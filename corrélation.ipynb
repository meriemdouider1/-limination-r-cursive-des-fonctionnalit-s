# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/Elimination-recursive-des-fonctionnalit-s/blob/main/corr%C3%A9lation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# %%
def eta_squared(x,y):
    moyenne_y = np.mean(y)
    classes = []
    for classe in x.unique():
        yi_classe = y[x==classe]
        classes.append({'ni': len(yi_classe),
                        'moyenne_classe': np.mean(yi_classe)})
    SCT = np.sum([(yj-moyenne_y)**2 for yj in y])
    SCE = np.sum([c['ni']*(c['moyenne_classe']-moyenne_y)**2 for c in classes])
    return SCE/SCT

# %% [markdown]
# # cs_longia

# %%
Cl1 = '/content/cs_longiadés.xlsx' 
data1=pd.read_excel(Cl1, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
del data1["Source"] 
del data1["CodeSite"] 
data1
# Out:
#         X_long      Y_lat  Cs_longia  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0   -15.911420  23.794740          1  ...       5.4       5.5       4.9
# 1   -13.188370  27.132950          1  ...       4.3       3.7       3.8
# 2   -13.188370  27.132950          1  ...       4.3       3.7       3.8
# 3   -13.185620  27.157940          0  ...       4.1       3.7       3.9
# 4   -13.167180  27.157730          0  ...       4.2       3.6       3.8
# ..         ...        ...        ...  ...       ...       ...       ...
# 255  -5.366667  35.766667          1  ...       4.0       4.0       4.2
# 256  -5.816667  35.783333          1  ...       3.6       3.8       4.0
# 257  -5.366667  35.833333          1  ...       4.0       3.9       4.3
# 258  -5.558611  35.841944          1  ...       3.6       3.4       3.6
# 259  -5.483333  35.900000          1  ...       4.0       4.0       4.2
#
# [260 rows x 226 columns]

# %%
data1["Cs_longia"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 255    1
# 256    1
# 257    1
# 258    1
# 259    1
# Name: Cs_longia, Length: 260, dtype: int64

# %%
A1 = data1.loc[:, data1.columns != 'Cs_longia']
x1 = data1.Cs_longia

# %%
T1=A1.columns

# %%
T1
# Out:
# Index(['X_long', 'Y_lat', 'Bovins', 'Volaille', 'Caprins', 'Ovins', 'Equides',
#        'Coniferes', 'ZoneAride', 'ZonePel',
#        ...
#        'Vent_Mars', 'Vent_Avril', 'Vent_Mai', 'Vent_Juin', 'Vent_Juill',
#        'Vent_Aout', 'Vent_Sept', 'Vent_Oct', 'Vent_Nov', 'Vent_Dec'],
#       dtype='object', length=225)

# %%
lst1=[]

# %%
for variable in T1 :
  y=A1[variable]
  print("variable : ",variable,"/corrélation:",eta_squared(x1,y))
  lst1.append([variable,eta_squared(x1,y)])
# Out:
# variable :  X_long /corrélation: 0.015511934443934283
# variable :  Y_lat /corrélation: 0.021808999072884465
# variable :  Bovins /corrélation: 0.014364109675052613
# variable :  Volaille /corrélation: 0.0020336755646138583
# variable :  Caprins /corrélation: 0.00930119597510238
# variable :  Ovins /corrélation: 0.03280415662863285
# variable :  Equides /corrélation: 0.02299030297800014
# variable :  Coniferes /corrélation: 0.0030559397005069035
# variable :  ZoneAride /corrélation: 0.04063716232441656
# variable :  ZonePel /corrélation: 0.00010785165012901103
# variable :  Lesfeuillus /corrélation: 0.006895598966618223
# variable :  Caduc /corrélation: 0.00010877029990650057
# variable :  Autres /corrélation: 0.0016975242997642297
# variable :  Arbrisseau /corrélation: 0.015524956991411364
# variable :  Pl_herb /corrélation: 0.014427626983235
# variable :  VegCul /corrélation: 0.045404635703153035
# variable :  VegInond /corrélation: 0.0009764016404724401
# ...

# %%
lst1
# Out:
# [['X_long', 0.015511934443934283],
#  ['Y_lat', 0.021808999072884465],
#  ['Bovins', 0.014364109675052613],
#  ['Volaille', 0.0020336755646138583],
#  ['Caprins', 0.00930119597510238],
#  ['Ovins', 0.03280415662863285],
#  ['Equides', 0.02299030297800014],
#  ['Coniferes', 0.0030559397005069035],
#  ['ZoneAride', 0.04063716232441656],
#  ['ZonePel', 0.00010785165012901103],
#  ['Lesfeuillus', 0.006895598966618223],
#  ['Caduc', 0.00010877029990650057],
#  ['Autres', 0.0016975242997642297],
#  ['Arbrisseau', 0.015524956991411364],
#  ['Pl_herb', 0.014427626983235],
#  ['VegCul', 0.045404635703153035],
#  ['VegInond', 0.0009764016404724401],
#  ['ZoneUrbaine', 0.0025953492875536027],
#  ['Moy_IRM', 0.05424104323908464],
#  ['Amp1_IRM', 0.01779266701803317],
#  ['Amp2_IRM', 0.003951556153265615],
#  ['Amp3_IRM', 0.03961278059774392],
#  ['VarT_ann_IRM', 0.0025029412693398094],
#  ['VarT_bi_IRM', 0.0021439488080631213],
#  ['VarT_tri_IRM', 0.006620250312795249],
# ...

# %%
df1 = pd.DataFrame(lst1, columns = ['variable','corrélation'])
print(df1)
# Out:
#       variable  corrélation
# 0       X_long     0.015512
# 1        Y_lat     0.021809
# 2       Bovins     0.014364
# 3     Volaille     0.002034
# 4      Caprins     0.009301
# ..         ...          ...
# 670  Vent_Aout     0.027407
# 671  Vent_Sept     0.058075
# 672   Vent_Oct     0.052592
# 673   Vent_Nov     0.024488
# 674   Vent_Dec     0.051549
#
# [675 rows x 2 columns]

# %%
df1.to_excel("cs_longia_corrélation.xlsx")

# %% [markdown]
# # cx_pipiens

# %%
Cl2 = '/content/cx_pipiensdés.xlsx' 
data2=pd.read_excel(Cl2, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
del data2["Source"] 
del data2["CodeSite"] 
data2
# Out:
#         X_long      Y_lat  Cx_pipiens  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0   -15.911420  23.794740           0  ...       5.4       5.5       4.9
# 1   -13.188370  27.132950           0  ...       4.3       3.7       3.8
# 2   -13.188370  27.132950           0  ...       4.3       3.7       3.8
# 3   -13.185620  27.157940           1  ...       4.1       3.7       3.9
# 4   -13.167180  27.157730           1  ...       4.2       3.6       3.8
# ..         ...        ...         ...  ...       ...       ...       ...
# 355  -5.833954  35.759465           1  ...       3.5       3.8       3.9
# 356  -5.366667  35.766667           1  ...       4.0       4.0       4.2
# 357  -5.360864  35.801733           1  ...       4.0       3.9       3.8
# 358  -5.366667  35.833333           1  ...       4.0       3.9       4.3
# 359  -5.483333  35.900000           1  ...       4.0       4.0       4.2
#
# [360 rows x 226 columns]

# %%
data2["Cx_pipiens"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 355    1
# 356    1
# 357    1
# 358    1
# 359    1
# Name: Cx_pipiens, Length: 360, dtype: int64

# %%
A2 = data2.loc[:, data2.columns != 'Cx_pipiens']
x2 = data2.Cx_pipiens

# %%
T2=A2.columns

# %%
T2
# Out:
# Index(['X_long', 'Y_lat', 'Bovins', 'Volaille', 'Caprins', 'Ovins', 'Equides',
#        'Coniferes', 'ZoneAride', 'ZonePel',
#        ...
#        'Vent_Mars', 'Vent_Avril', 'Vent_Mai', 'Vent_Juin', 'Vent_Juill',
#        'Vent_Aout', 'Vent_Sept', 'Vent_Oct', 'Vent_Nov', 'Vent_Dec'],
#       dtype='object', length=225)

# %%
lst2=[]

# %%
for variable in T2 :
  y2=A2[variable]
  print("variable : ",variable,"/corrélation:",eta_squared(x2,y2))
  lst2.append([variable,eta_squared(x2,y2)])
# Out:
# variable :  X_long /corrélation: 0.011661095190271361
# variable :  Y_lat /corrélation: 0.019575214935657923
# variable :  Bovins /corrélation: 0.0037137246160753225
# variable :  Volaille /corrélation: 0.011635255118611533
# variable :  Caprins /corrélation: 0.010848769080038921
# variable :  Ovins /corrélation: 8.810761082432081e-06
# variable :  Equides /corrélation: 0.0015275292130878504
# variable :  Coniferes /corrélation: 0.007347251943777874
# variable :  ZoneAride /corrélation: 0.0015265343229496197
# variable :  ZonePel /corrélation: 0.0004560435365505025
# variable :  Lesfeuillus /corrélation: 0.015145355635244426
# variable :  Caduc /corrélation: 0.006376277224577142
# variable :  Autres /corrélation: 0.0033631259186516047
# variable :  Arbrisseau /corrélation: 0.0034372134284687125
# variable :  Pl_herb /corrélation: 0.0030552542062347483
# variable :  VegCul /corrélation: 0.0006140764746593271
# variable :  VegInond /corrélation: 0.002295128038702684
# ...

# %%
lst2
# Out:
# [['X_long', 0.011661095190271361],
#  ['Y_lat', 0.019575214935657923],
#  ['Bovins', 0.0037137246160753225],
#  ['Volaille', 0.011635255118611533],
#  ['Caprins', 0.010848769080038921],
#  ['Ovins', 8.810761082432081e-06],
#  ['Equides', 0.0015275292130878504],
#  ['Coniferes', 0.007347251943777874],
#  ['ZoneAride', 0.0015265343229496197],
#  ['ZonePel', 0.0004560435365505025],
#  ['Lesfeuillus', 0.015145355635244426],
#  ['Caduc', 0.006376277224577142],
#  ['Autres', 0.0033631259186516047],
#  ['Arbrisseau', 0.0034372134284687125],
#  ['Pl_herb', 0.0030552542062347483],
#  ['VegCul', 0.0006140764746593271],
#  ['VegInond', 0.002295128038702684],
#  ['ZoneUrbaine', 6.733873291344925e-05],
#  ['Moy_IRM', 2.1339358681495387e-06],
#  ['Amp1_IRM', 0.003441875963143224],
#  ['Amp2_IRM', 3.422689668018824e-05],
#  ['Amp3_IRM', 0.011252889660752337],
#  ['VarT_ann_IRM', 0.003847904778555575],
#  ['VarT_bi_IRM', 0.008695531192609497],
#  ['VarT_tri_IRM', 0.0009617842584858369],
# ...

# %%
df2 = pd.DataFrame(lst2, columns = ['variable','corrélation'])
print(df2)
# Out:
#       variable  corrélation
# 0       X_long     0.011661
# 1        Y_lat     0.019575
# 2       Bovins     0.003714
# 3     Volaille     0.011635
# 4      Caprins     0.010849
# ..         ...          ...
# 220  Vent_Aout     0.000411
# 221  Vent_Sept     0.013074
# 222   Vent_Oct     0.021675
# 223   Vent_Nov     0.006020
# 224   Vent_Dec     0.022163
#
# [225 rows x 2 columns]

# %%
df2.to_excel("cx_pipiens_corrélation.xlsx")

# %% [markdown]
# # cx_theileri

# %%
Cl3 = '/content/cx_theildés.xlsx' 
data3=pd.read_excel(Cl3, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
del data3["Source"] 
del data3["CodeSite"] 
data3
# Out:
#         X_long      Y_lat  Cx_theileri  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0   -15.911420  23.794740            0  ...       5.4       5.5       4.9
# 1   -13.188370  27.132950            0  ...       4.3       3.7       3.8
# 2   -13.188370  27.132950            0  ...       4.3       3.7       3.8
# 3   -13.185620  27.157940            1  ...       4.1       3.7       3.9
# 4   -13.167180  27.157730            0  ...       4.2       3.6       3.8
# ..         ...        ...          ...  ...       ...       ...       ...
# 296  -5.283333  35.633333            1  ...       3.9       3.4       3.8
# 297  -5.325286  35.685852            1  ...       4.0       3.9       4.3
# 298  -5.833954  35.759465            1  ...       3.5       3.8       3.9
# 299  -5.366667  35.766667            1  ...       4.0       4.0       4.2
# 300  -5.816667  35.783333            1  ...       3.6       3.8       4.0
#
# [301 rows x 226 columns]

# %%
data3["Cx_theileri"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 296    1
# 297    1
# 298    1
# 299    1
# 300    1
# Name: Cx_theileri, Length: 301, dtype: int64

# %%
A3 = data3.loc[:, data3.columns != 'Cx_theileri']
x3 = data3.Cx_theileri

# %%
T3=A3.columns

# %%
T3
# Out:
# Index(['X_long', 'Y_lat', 'Bovins', 'Volaille', 'Caprins', 'Ovins', 'Equides',
#        'Coniferes', 'ZoneAride', 'ZonePel',
#        ...
#        'Vent_Mars', 'Vent_Avril', 'Vent_Mai', 'Vent_Juin', 'Vent_Juill',
#        'Vent_Aout', 'Vent_Sept', 'Vent_Oct', 'Vent_Nov', 'Vent_Dec'],
#       dtype='object', length=225)

# %%
lst3=[]

# %%
for variable in T3 :
  y3=A3[variable]
  print("variable : ",variable,"/corrélation:",eta_squared(x3,y3))
  lst3.append([variable,eta_squared(x3,y3)])
# Out:
# variable :  X_long /corrélation: 0.043956195608981764
# variable :  Y_lat /corrélation: 0.051483234055392416
# variable :  Bovins /corrélation: 0.00023295375524008343
# variable :  Volaille /corrélation: 0.0032283578931530774
# variable :  Caprins /corrélation: 0.007536979576599331
# variable :  Ovins /corrélation: 0.0019802384581775294
# variable :  Equides /corrélation: 0.0026092769235778724
# variable :  Coniferes /corrélation: 0.0067397870322522795
# variable :  ZoneAride /corrélation: 0.005587443648620835
# variable :  ZonePel /corrélation: 0.0006249893004933388
# variable :  Lesfeuillus /corrélation: 0.008382917619101619
# variable :  Caduc /corrélation: 0.002897148660048251
# variable :  Autres /corrélation: 0.002080062312527479
# variable :  Arbrisseau /corrélation: 0.0056363238202164975
# variable :  Pl_herb /corrélation: 0.011979687171456347
# variable :  VegCul /corrélation: 0.00010680656734964454
# variable :  VegInond /corrélation: 0.010947256913470114
# ...

# %%
lst3
# Out:
# [['X_long', 0.043956195608981764],
#  ['Y_lat', 0.051483234055392416],
#  ['Bovins', 0.00023295375524008343],
#  ['Volaille', 0.0032283578931530774],
#  ['Caprins', 0.007536979576599331],
#  ['Ovins', 0.0019802384581775294],
#  ['Equides', 0.0026092769235778724],
#  ['Coniferes', 0.0067397870322522795],
#  ['ZoneAride', 0.005587443648620835],
#  ['ZonePel', 0.0006249893004933388],
#  ['Lesfeuillus', 0.008382917619101619],
#  ['Caduc', 0.002897148660048251],
#  ['Autres', 0.002080062312527479],
#  ['Arbrisseau', 0.0056363238202164975],
#  ['Pl_herb', 0.011979687171456347],
#  ['VegCul', 0.00010680656734964454],
#  ['VegInond', 0.010947256913470114],
#  ['ZoneUrbaine', 0.00012534896721963282],
#  ['Moy_IRM', 0.00025937741595552597],
#  ['Amp1_IRM', 0.004822107880569796],
#  ['Amp2_IRM', 0.013695535700919999],
#  ['Amp3_IRM', 0.010342502503669165],
#  ['VarT_ann_IRM', 0.0038581500611723865],
#  ['VarT_bi_IRM', 0.008713857362038977],
#  ['VarT_tri_IRM', 0.009327079378011334],
# ...

# %%
df3 = pd.DataFrame(lst3, columns = ['variable','corrélation'])
print(df3)
# Out:
#       variable  corrélation
# 0       X_long     0.043956
# 1        Y_lat     0.051483
# 2       Bovins     0.000233
# 3     Volaille     0.003228
# 4      Caprins     0.007537
# ..         ...          ...
# 220  Vent_Aout     0.072152
# 221  Vent_Sept     0.030143
# 222   Vent_Oct     0.033817
# 223   Vent_Nov     0.039379
# 224   Vent_Dec     0.026397
#
# [225 rows x 2 columns]

# %%
df3.to_excel("cx_theileri_corrélation.xlsx")
