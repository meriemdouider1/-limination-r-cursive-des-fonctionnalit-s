# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/-limination-r-cursive-des-fonctionnalit-s/blob/main/Recursive_Feature_Elimination_(RFE)_for_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier

# %%
Cl = '/content/cs-longia.xlsx' 
data= pd.read_excel(Cl, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
del data["Source"] 
del data["CodeSite"] 
data
# Out:
#         X_long      Y_lat  Cs_longia  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0   -15.911420  23.794740          1  ...       5.4       5.5       4.9
# 1   -13.188370  27.132950          1  ...       4.3       3.7       3.8
# 2   -13.188370  27.132950          1  ...       4.3       3.7       3.8
# 3   -13.185620  27.157940          0  ...       4.1       3.7       3.9
# 4   -13.167180  27.157730          0  ...       4.2       3.6       3.8
# ..         ...        ...        ...  ...       ...       ...       ...
# 249  -5.366667  35.766667          1  ...       4.0       4.0       4.2
# 250  -5.816667  35.783333          1  ...       3.6       3.8       4.0
# 251  -5.366667  35.833333          1  ...       4.0       3.9       4.3
# 252  -5.558611  35.841944          1  ...       3.6       3.4       3.6
# 253  -5.483333  35.900000          1  ...       4.0       4.0       4.2
#
# [254 rows x 226 columns]

# %%
X = data.loc[:, data.columns != 'Cs_longia']
Y = data.Cs_longia

# %%
X
# Out:
#         X_long      Y_lat    Bovins  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0   -15.911420  23.794740  0.000000  ...       5.4       5.5       4.9
# 1   -13.188370  27.132950  0.000214  ...       4.3       3.7       3.8
# 2   -13.188370  27.132950  0.000214  ...       4.3       3.7       3.8
# 3   -13.185620  27.157940  0.000000  ...       4.1       3.7       3.9
# 4   -13.167180  27.157730  0.000000  ...       4.2       3.6       3.8
# ..         ...        ...       ...  ...       ...       ...       ...
# 249  -5.366667  35.766667  8.495770  ...       4.0       4.0       4.2
# 250  -5.816667  35.783333  0.000000  ...       3.6       3.8       4.0
# 251  -5.366667  35.833333  7.411978  ...       4.0       3.9       4.3
# 252  -5.558611  35.841944  5.696193  ...       3.6       3.4       3.6
# 253  -5.483333  35.900000  6.839514  ...       4.0       4.0       4.2
#
# [254 rows x 225 columns]

# %%
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 249    1
# 250    1
# 251    1
# 252    1
# 253    1
# Name: Cs_longia, Length: 254, dtype: int64

# %%
def tp(y_true, y_pred):
  specificite= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
  return specificite
my_scorer = make_scorer(tp, greater_is_better=True)
def tp1(y_true, y_pred):
  MCC= matthews_corrcoef(y_true, y_pred) 
  return MCC
my_scorer1 = make_scorer(tp1, greater_is_better=True)

# %%
# evaluate RFE for classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
import xgboost as xgb
# create pipeline
rfe = RFE(estimator=XGBClassifier(scale_pos_weight=1.5,
learning_rate=0.1,max_depth=5,n_estimators=100), n_features_to_select=15)
model = XGBClassifier(scale_pos_weight=1.5,
learning_rate=0.1,max_depth=5,n_estimators=100)
pipeline = Pipeline(steps=[('s',rfe),('m',model)])
# evaluate model
cv = KFold(n_splits=5, random_state=1, shuffle=True)
# evaluate model
scores = cross_val_score(pipeline, X, Y, scoring='accuracy', cv=cv, n_jobs=-1,error_score='raise')
scores1 = cross_val_score(pipeline, X, Y, scoring='precision', cv=cv, n_jobs=-1)
scores2 = cross_val_score(pipeline, X, Y, scoring='recall', cv=cv, n_jobs=-1)
scores3 = cross_val_score(pipeline, X, Y, scoring=my_scorer, cv=cv, n_jobs=-1)
scores4 = cross_val_score(pipeline, X, Y, scoring=my_scorer1, cv=cv, n_jobs=-1)
# report performance
print('Accuracy:',scores)
print('moy_accuracy: %.2f' % mean(scores))
print('precision:',scores1)
print('moy_precision: %.2f' % mean(scores1))
print('sensibilité :',scores2)
print('moy_sensibilité: %.2f' % mean(scores2))
print('spécificité :',scores3)
print('moy_spécificité: %.2f' % mean(scores3))
print('MCC :',scores4)
print('MCC: %.2f' % mean(scores4))
# Out:
# Accuracy: [0.64705882 0.56862745 0.62745098 0.66666667 0.62      ]
# moy_accuracy: 0.63
# precision: [0.76       0.5        0.67741935 0.57142857 0.5862069 ]
# moy_precision: 0.62
# sensibilité : [0.61290323 0.77272727 0.7        0.6        0.70833333]
# moy_sensibilité: 0.68
# spécificité : [0.7        0.4137931  0.52380952 0.70967742 0.53846154]
# moy_spécificité: 0.58
# MCC : [0.30559708 0.19596238 0.22560722 0.30720983 0.24981573]
# MCC: 0.26

# %%
# evaluate RFE for classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
import xgboost as xgb
# create pipeline
rfe = RFE(estimator=XGBClassifier(scale_pos_weight=1.5,
learning_rate=0.1,max_depth=5,n_estimators=100), n_features_to_select=10)
model = XGBClassifier(scale_pos_weight=1.5,
learning_rate=0.1,max_depth=5,n_estimators=100)
pipeline = Pipeline(steps=[('s',rfe),('m',model)])
# evaluate model
cv = KFold(n_splits=5, random_state=1, shuffle=True)
scores4 = cross_val_score(pipeline, X, Y, scoring=my_scorer1, cv=cv, n_jobs=-1)
# report performance
print('MCC :',scores4)
print('MCC: %.2f' % mean(scores4))
# Out:
# MCC : [0.24054969 0.32650492 0.23659777 0.49777669 0.36217949]
# MCC: 0.33

# %%
# create pipeline
rfe = RFECV(estimator=XGBClassifier(scale_pos_weight=1.5,
learning_rate=0.1,max_depth=5,n_estimators=100))
model = XGBClassifier(scale_pos_weight=1.5,
learning_rate=0.1,max_depth=5,n_estimators=100)
pipeline = Pipeline(steps=[('s',rfe),('m',model)])
# evaluate model
cv = KFold(n_splits=5, random_state=1, shuffle=True)
scores4 = cross_val_score(pipeline, X, Y, scoring=my_scorer1, cv=cv, n_jobs=-1)
# report performance
print('MCC :',scores4)
print('MCC: %.2f' % mean(scores4))
# Out:
# MCC : [ 0.24717366  0.22904222  0.26253205 -0.04560478  0.1638559 ]
# MCC: 0.17

# %%
# report which features were selected by RFE
from sklearn.datasets import make_classification
from sklearn.feature_selection import RFE   
from sklearn.tree import DecisionTreeClassifier
rfe = RFE(estimator=XGBClassifier(scale_pos_weight=1.5,
learning_rate=0.1,max_depth=5,n_estimators=100), n_features_to_select=10)
# fit RFE
rfe.fit(X, Y)
# summarize all features
for i in range(X.shape[1]):
	print('Column: %d, Selected %s, Rank: %.3f' % (i, rfe.support_[i], rfe.ranking_[i]))
# Out:
# Column: 0, Selected False, Rank: 78.000
# Column: 1, Selected False, Rank: 46.000
# Column: 2, Selected False, Rank: 115.000
# Column: 3, Selected False, Rank: 176.000
# Column: 4, Selected False, Rank: 174.000
# Column: 5, Selected False, Rank: 12.000
# Column: 6, Selected False, Rank: 67.000
# Column: 7, Selected False, Rank: 169.000
# Column: 8, Selected False, Rank: 177.000
# Column: 9, Selected False, Rank: 182.000
# Column: 10, Selected False, Rank: 185.000
# Column: 11, Selected False, Rank: 188.000
# Column: 12, Selected False, Rank: 189.000
# Column: 13, Selected False, Rank: 159.000
# Column: 14, Selected False, Rank: 44.000
# Column: 15, Selected False, Rank: 123.000
# Column: 16, Selected False, Rank: 193.000
# Column: 17, Selected False, Rank: 195.000
# Column: 18, Selected False, Rank: 42.000
# Column: 19, Selected False, Rank: 136.000
# Column: 20, Selected False, Rank: 58.000
# Column: 21, Selected False, Rank: 133.000
# Column: 22, Selected False, Rank: 100.000
# Column: 23, Selected False, Rank: 108.000
# Column: 24, Selected False, Rank: 207.000
# Column: 25, Selected False, Rank: 17.000
# Column: 26, Selected True, Rank: 1.000
# Column: 27, Selected False, Rank: 48.000
# Column: 28, Selected False, Rank: 157.000
# Column: 29, Selected False, Rank: 102.000
# Column: 30, Selected False, Rank: 66.000
# Column: 31, Selected False, Rank: 210.000
# Column: 32, Selected False, Rank: 5.000
# Column: 33, Selected False, Rank: 71.000
# Column: 34, Selected False, Rank: 148.000
# Column: 35, Selected True, Rank: 1.000
# Column: 36, Selected False, Rank: 215.000
# Column: 37, Selected False, Rank: 150.000
# Column: 38, Selected False, Rank: 198.000
# Column: 39, Selected False, Rank: 128.000
# Column: 40, Selected True, Rank: 1.000
# Column: 41, Selected False, Rank: 24.000
# Column: 42, Selected False, Rank: 4.000
# Column: 43, Selected False, Rank: 28.000
# Column: 44, Selected False, Rank: 35.000
# Column: 45, Selected False, Rank: 104.000
# Column: 46, Selected False, Rank: 140.000
# Column: 47, Selected False, Rank: 84.000
# Column: 48, Selected False, Rank: 30.000
# Column: 49, Selected False, Rank: 76.000
# Column: 50, Selected False, Rank: 106.000
# Column: 51, Selected False, Rank: 180.000
# Column: 52, Selected False, Rank: 208.000
# Column: 53, Selected False, Rank: 171.000
# Column: 54, Selected False, Rank: 125.000
# Column: 55, Selected True, Rank: 1.000
# Column: 56, Selected False, Rank: 127.000
# Column: 57, Selected False, Rank: 82.000
# Column: 58, Selected False, Rank: 79.000
# Column: 59, Selected False, Rank: 166.000
# Column: 60, Selected False, Rank: 109.000
# Column: 61, Selected False, Rank: 72.000
# Column: 62, Selected False, Rank: 37.000
# Column: 63, Selected False, Rank: 190.000
# Column: 64, Selected False, Rank: 22.000
# Column: 65, Selected False, Rank: 53.000
# Column: 66, Selected False, Rank: 34.000
# Column: 67, Selected False, Rank: 132.000
# Column: 68, Selected False, Rank: 146.000
# Column: 69, Selected False, Rank: 7.000
# Column: 70, Selected False, Rank: 9.000
# Column: 71, Selected False, Rank: 36.000
# Column: 72, Selected False, Rank: 95.000
# Column: 73, Selected False, Rank: 23.000
# Column: 74, Selected True, Rank: 1.000
# Column: 75, Selected False, Rank: 16.000
# Column: 76, Selected False, Rank: 89.000
# Column: 77, Selected False, Rank: 168.000
# Column: 78, Selected False, Rank: 129.000
# Column: 79, Selected False, Rank: 98.000
# Column: 80, Selected False, Rank: 26.000
# Column: 81, Selected False, Rank: 15.000
# Column: 82, Selected False, Rank: 158.000
# Column: 83, Selected False, Rank: 63.000
# Column: 84, Selected False, Rank: 73.000
# Column: 85, Selected False, Rank: 120.000
# Column: 86, Selected False, Rank: 54.000
# Column: 87, Selected True, Rank: 1.000
# Column: 88, Selected False, Rank: 135.000
# Column: 89, Selected False, Rank: 81.000
# Column: 90, Selected False, Rank: 8.000
# Column: 91, Selected False, Rank: 10.000
# Column: 92, Selected False, Rank: 20.000
# Column: 93, Selected False, Rank: 121.000
# Column: 94, Selected False, Rank: 55.000
# Column: 95, Selected False, Rank: 113.000
# Column: 96, Selected False, Rank: 21.000
# Column: 97, Selected False, Rank: 75.000
# Column: 98, Selected False, Rank: 56.000
# Column: 99, Selected False, Rank: 83.000
# Column: 100, Selected False, Rank: 111.000
# Column: 101, Selected False, Rank: 156.000
# Column: 102, Selected False, Rank: 184.000
# Column: 103, Selected False, Rank: 134.000
# Column: 104, Selected False, Rank: 151.000
# Column: 105, Selected False, Rank: 62.000
# Column: 106, Selected False, Rank: 154.000
# Column: 107, Selected False, Rank: 18.000
# Column: 108, Selected False, Rank: 27.000
# Column: 109, Selected False, Rank: 137.000
# Column: 110, Selected False, Rank: 211.000
# Column: 111, Selected False, Rank: 162.000
# Column: 112, Selected False, Rank: 101.000
# Column: 113, Selected False, Rank: 116.000
# Column: 114, Selected False, Rank: 49.000
# Column: 115, Selected False, Rank: 99.000
# Column: 116, Selected False, Rank: 96.000
# Column: 117, Selected False, Rank: 50.000
# Column: 118, Selected False, Rank: 97.000
# Column: 119, Selected False, Rank: 61.000
# Column: 120, Selected False, Rank: 69.000
# Column: 121, Selected False, Rank: 86.000
# Column: 122, Selected True, Rank: 1.000
# Column: 123, Selected False, Rank: 38.000
# Column: 124, Selected False, Rank: 112.000
# Column: 125, Selected False, Rank: 165.000
# Column: 126, Selected False, Rank: 93.000
# Column: 127, Selected False, Rank: 33.000
# Column: 128, Selected False, Rank: 43.000
# Column: 129, Selected False, Rank: 77.000
# Column: 130, Selected False, Rank: 143.000
# Column: 131, Selected False, Rank: 126.000
# Column: 132, Selected False, Rank: 205.000
# Column: 133, Selected False, Rank: 194.000
# Column: 134, Selected False, Rank: 47.000
# Column: 135, Selected False, Rank: 39.000
# Column: 136, Selected False, Rank: 139.000
# Column: 137, Selected False, Rank: 19.000
# Column: 138, Selected False, Rank: 85.000
# Column: 139, Selected False, Rank: 40.000
# Column: 140, Selected False, Rank: 3.000
# Column: 141, Selected False, Rank: 103.000
# Column: 142, Selected False, Rank: 70.000
# Column: 143, Selected False, Rank: 160.000
# Column: 144, Selected False, Rank: 201.000
# Column: 145, Selected False, Rank: 173.000
# Column: 146, Selected False, Rank: 60.000
# Column: 147, Selected False, Rank: 206.000
# Column: 148, Selected False, Rank: 13.000
# Column: 149, Selected False, Rank: 14.000
# Column: 150, Selected False, Rank: 124.000
# Column: 151, Selected False, Rank: 65.000
# Column: 152, Selected False, Rank: 80.000
# Column: 153, Selected False, Rank: 202.000
# Column: 154, Selected False, Rank: 199.000
# Column: 155, Selected False, Rank: 175.000
# Column: 156, Selected False, Rank: 192.000
# Column: 157, Selected False, Rank: 200.000
# Column: 158, Selected False, Rank: 203.000
# Column: 159, Selected True, Rank: 1.000
# Column: 160, Selected False, Rank: 161.000
# Column: 161, Selected False, Rank: 147.000
# Column: 162, Selected False, Rank: 172.000
# Column: 163, Selected False, Rank: 114.000
# Column: 164, Selected False, Rank: 68.000
# Column: 165, Selected False, Rank: 145.000
# Column: 166, Selected False, Rank: 164.000
# Column: 167, Selected False, Rank: 142.000
# Column: 168, Selected False, Rank: 122.000
# Column: 169, Selected False, Rank: 59.000
# Column: 170, Selected False, Rank: 29.000
# Column: 171, Selected False, Rank: 94.000
# Column: 172, Selected False, Rank: 52.000
# Column: 173, Selected False, Rank: 90.000
# Column: 174, Selected False, Rank: 183.000
# Column: 175, Selected False, Rank: 179.000
# Column: 176, Selected False, Rank: 138.000
# Column: 177, Selected False, Rank: 45.000
# Column: 178, Selected False, Rank: 6.000
# Column: 179, Selected False, Rank: 74.000
# Column: 180, Selected True, Rank: 1.000
# Column: 181, Selected False, Rank: 31.000
# Column: 182, Selected False, Rank: 212.000
# Column: 183, Selected False, Rank: 87.000
# Column: 184, Selected False, Rank: 213.000
# Column: 185, Selected False, Rank: 57.000
# Column: 186, Selected False, Rank: 181.000
# Column: 187, Selected False, Rank: 117.000
# Column: 188, Selected False, Rank: 170.000
# Column: 189, Selected False, Rank: 196.000
# Column: 190, Selected False, Rank: 131.000
# Column: 191, Selected False, Rank: 130.000
# Column: 192, Selected False, Rank: 209.000
# Column: 193, Selected False, Rank: 105.000
# Column: 194, Selected False, Rank: 155.000
# Column: 195, Selected False, Rank: 92.000
# Column: 196, Selected False, Rank: 107.000
# Column: 197, Selected False, Rank: 204.000
# Column: 198, Selected False, Rank: 118.000
# Column: 199, Selected False, Rank: 149.000
# Column: 200, Selected False, Rank: 197.000
# Column: 201, Selected False, Rank: 91.000
# Column: 202, Selected False, Rank: 64.000
# Column: 203, Selected False, Rank: 178.000
# Column: 204, Selected False, Rank: 191.000
# Column: 205, Selected False, Rank: 153.000
# Column: 206, Selected False, Rank: 144.000
# Column: 207, Selected False, Rank: 187.000
# Column: 208, Selected False, Rank: 167.000
# Column: 209, Selected False, Rank: 119.000
# Column: 210, Selected False, Rank: 2.000
# Column: 211, Selected False, Rank: 214.000
# Column: 212, Selected False, Rank: 216.000
# Column: 213, Selected False, Rank: 41.000
# Column: 214, Selected False, Rank: 110.000
# Column: 215, Selected False, Rank: 11.000
# Column: 216, Selected False, Rank: 141.000
# Column: 217, Selected False, Rank: 51.000
# Column: 218, Selected True, Rank: 1.000
# Column: 219, Selected False, Rank: 186.000
# Column: 220, Selected False, Rank: 32.000
# Column: 221, Selected False, Rank: 88.000
# Column: 222, Selected False, Rank: 163.000
# Column: 223, Selected False, Rank: 152.000
# Column: 224, Selected False, Rank: 25.000
