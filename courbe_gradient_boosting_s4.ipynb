# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/Elimination-recursive-des-fonctionnalit-s/blob/main/courbe_gradient_boosting_s4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# # Min_IRM

# %% [markdown]
# **apprentissage absence**

# %%
Cl11 = '/content/Min_IRM_absapp.xlsx' 
abs_app_min_irm= pd.read_excel(Cl11, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_app_min_irm
# Out:
#     Cs_longia  predict  predict0  predict1  Min_IRM
# 0           0        0  0.963547  0.036453      340
# 1           0        0  0.987481  0.012519      570
# 2           0        0  0.915492  0.084508      620
# 3           0        0  0.683701  0.316299      640
# 4           0        0  0.822017  0.177983      650
# ..        ...      ...       ...       ...      ...
# 89          0        0  0.922559  0.077441     2620
# 90          0        0  0.741283  0.258717     2930
# 91          0        0  0.881563  0.118437     3110
# 92          0        0  0.615408  0.384592     3120
# 93          0        0  0.947627  0.052373     3170
#
# [94 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

y = abs_app_min_irm["predict0"]
x = abs_app_min_irm["Min_IRM"]
plt.plot(x, y,"r")
plt.title('Apprentissage-absence MIN_IRM')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **apprentissage presence**

# %%
Cl12 = '/content/Min_IRM_preapp.xlsx' 
pre_app_min_irm= pd.read_excel(Cl12, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_app_min_irm
# Out:
#      Cs_longia  predict  predict0  predict1  Min_IRM
# 0            1        1  0.106390  0.893610      550
# 1            1        1  0.043810  0.956190      650
# 2            1        1  0.043810  0.956190      650
# 3            1        1  0.291590  0.708410      740
# 4            1        1  0.016738  0.983262      810
# ..         ...      ...       ...       ...      ...
# 97           1        1  0.009833  0.990167     3490
# 98           1        1  0.010574  0.989426     3620
# 99           1        1  0.024242  0.975758     3670
# 100          1        1  0.023672  0.976328     3710
# 101          1        1  0.118571  0.881429     4060
#
# [102 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_app_min_irm["predict1"]
x = pre_app_min_irm["Min_IRM"]
plt.plot(x, y,"r")
plt.title('Apprentissage-presence MIN_IRM')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val absence**

# %%
Cl13 = '/content/Min_irm_absval.xlsx' 
abs_val_min_irm= pd.read_excel(Cl13, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_val_min_irm
# Out:
#     Cs_longia  predict  predict0  predict1  Min_IRM
# 0           0        0  0.721836  0.278164     1010
# 1           0        0  0.855130  0.144870     1090
# 2           0        0  0.938562  0.061438     1090
# 3           0        0  0.953758  0.046242     1110
# 4           0        0  0.560221  0.439779     1170
# 5           0        0  0.888156  0.111844     1210
# 6           0        0  0.941180  0.058820     1230
# 7           0        0  0.888156  0.111844     1250
# 8           0        0  0.871982  0.128018     1250
# 9           0        0  0.877161  0.122839     1280
# 10          0        0  0.852824  0.147176     1290
# 11          0        0  0.824535  0.175465     1420
# 12          0        0  0.595637  0.404363     1510
# 13          0        0  0.704766  0.295234     1650
# 14          0        0  0.955479  0.044521     1680
# 15          0        0  0.681849  0.318151     1770
# 16          0        0  0.961293  0.038707     1920
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

y = abs_val_min_irm["predict0"]
x = abs_val_min_irm["Min_IRM"]
plt.title('Validation-absence MIN_IRM')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val presence**

# %%
Cl14 = '/content/Min_IRM_preval.xlsx' 
pre_val_min_irm= pd.read_excel(Cl14, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_val_min_irm
# Out:
#     Cs_longia  predict  predict0  predict1  Min_IRM
# 0           1        1  0.068563  0.931437     1040
# 1           1        1  0.024510  0.975490     1350
# 2           1        1  0.207506  0.792494     1880
# 3           1        1  0.159595  0.840405     2070
# 4           1        1  0.092200  0.907800     2460
# 5           1        1  0.359125  0.640875     2560
# 6           1        1  0.052266  0.947734     2790
# 7           1        1  0.079594  0.920406     2830
# 8           1        1  0.005357  0.994643     2940
# 9           1        1  0.055254  0.944746     3190
# 10          1        1  0.024679  0.975321     3360
# 11          1        1  0.008249  0.991751     3550
# 12          1        1  0.014961  0.985039     3960
# 13          1        1  0.026526  0.973474     3990

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_val_min_irm["predict1"]
x = pre_val_min_irm["Min_IRM"]
plt.title('Validation-presence MIN_IRM')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # AMP1_tempJ

# %% [markdown]
# **apprentissage absence**

# %%
Cl21 = '/content/amp1_TempJ_absapp.xlsx' 
abs_app_amp1_tempJ= pd.read_excel(Cl21, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_app_amp1_tempJ
# Out:
#     Cs_longia  predict  predict0  predict1  Amp1_TempJ
# 0           0        0  0.987481  0.012519           0
# 1           0        0  0.901129  0.098871           0
# 2           0        0  0.915492  0.084508           0
# 3           0        0  0.963547  0.036453           0
# 4           0        0  0.556797  0.443203         232
# ..        ...      ...       ...       ...         ...
# 89          0        0  0.693382  0.306618         722
# 90          0        0  0.804061  0.195939         728
# 91          0        0  0.881563  0.118437         728
# 92          0        0  0.947627  0.052373         735
# 93          0        0  0.862145  0.137855         736
#
# [94 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

y = abs_app_amp1_tempJ["predict0"]
x = abs_app_amp1_tempJ["Amp1_TempJ"]
plt.plot(x, y,"r")
plt.title('Apprentissage-absence Amp1_TempJ')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **apprentissage presence**

# %%
Cl22 = '/content/Amp1_tempJ_preapp.xlsx' 
pre_app_amp1_TempJ= pd.read_excel(Cl22, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_app_amp1_TempJ
# Out:
#      Cs_longia  predict  predict0  predict1  Amp1_TempJ
# 0            1        1  0.172668  0.827332          96
# 1            1        1  0.016424  0.983576         229
# 2            1        1  0.055254  0.944746         288
# 3            1        1  0.057273  0.942727         289
# 4            1        1  0.011178  0.988822         312
# ..         ...      ...       ...       ...         ...
# 97           1        1  0.148777  0.851223         732
# 98           1        1  0.118571  0.881429         745
# 99           1        1  0.021882  0.978118         753
# 100          1        1  0.153934  0.846066         755
# 101          1        1  0.024242  0.975758         761
#
# [102 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_app_amp1_TempJ["predict1"]
x = pre_app_amp1_TempJ["Amp1_TempJ"]
plt.plot(x, y,"r")
plt.title('Apprentissage-presence Amp1_TempJ')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val absence**

# %%
Cl23 = '/content/Amp1_tempJ_absval.xlsx' 
abs_val_amp1_tempJ= pd.read_excel(Cl23, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_val_amp1_tempJ
# Out:
#     Cs_longia  predict  predict0  predict1  Amp1_TempJ
# 0           0        0  0.855130  0.144870         273
# 1           0        0  0.984033  0.015967         295
# 2           0        0  0.961293  0.038707         299
# 3           0        0  0.941180  0.058820         313
# 4           0        0  0.681849  0.318151         379
# 5           0        0  0.727151  0.272849         460
# 6           0        0  0.714717  0.285283         475
# 7           0        0  0.714717  0.285283         475
# 8           0        0  0.955479  0.044521         509
# 9           0        0  0.721836  0.278164         555
# 10          0        0  0.842887  0.157113         568
# 11          0        0  0.824535  0.175465         571
# 12          0        0  0.938562  0.061438         580
# 13          0        0  0.953758  0.046242         582
# 14          0        0  0.852824  0.147176         599
# 15          0        0  0.871982  0.128018         639
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

y = abs_val_amp1_tempJ["predict0"]
x = abs_val_amp1_tempJ["Amp1_TempJ"]
plt.title('Validation-absence Amp1_TempJ')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val presence**

# %%
Cl24 = '/content/Amp1_Tempj_preval.xlsx' 
pre_val_amp1_tempJ= pd.read_excel(Cl24, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_val_amp1_tempJ
# Out:
#     Cs_longia  predict  predict0  predict1  Amp1_TempJ
# 0           1        1  0.055254  0.944746         288
# 1           1        1  0.092200  0.907800         311
# 2           1        1  0.026526  0.973474         318
# 3           1        1  0.014961  0.985039         335
# 4           1        1  0.008249  0.991751         419
# 5           1        1  0.005357  0.994643         430
# 6           1        1  0.359125  0.640875         448
# 7           1        1  0.079594  0.920406         452
# 8           1        1  0.207506  0.792494         605
# 9           1        1  0.024679  0.975321         634
# 10          1        1  0.024510  0.975490         646
# 11          1        1  0.159595  0.840405         656
# 12          1        1  0.068563  0.931437         704
# 13          1        1  0.052266  0.947734         707

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_val_amp1_tempJ["predict1"]
x = pre_val_amp1_tempJ["Amp1_TempJ"]
plt.title('Validation-presence Amp1_TempJ')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Max_TempN

# %% [markdown]
# **apprentissage absence**

# %%
Cl31 = '/content/Max_TempN_absapp.xlsx' 
abs_app_Max_TempN= pd.read_excel(Cl31, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_app_Max_TempN
# Out:
#     Cs_longia  predict  predict0  predict1  Max_TempN
# 0           0        0  0.987481  0.012519          0
# 1           0        0  0.901129  0.098871          0
# 2           0        0  0.915492  0.084508          0
# 3           0        0  0.963547  0.036453          0
# 4           0        0  0.869950  0.130050      14368
# ..        ...      ...       ...       ...        ...
# 89          0        0  0.888156  0.111844      14869
# 90          0        0  0.947627  0.052373      14955
# 91          0        0  0.958585  0.041415      15020
# 92          0        0  0.919681  0.080319      15023
# 93          0        0  0.922559  0.077441      15042
#
# [94 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

y = abs_app_Max_TempN["predict0"]
x = abs_app_Max_TempN["Max_TempN"]
plt.plot(x, y,"r")
plt.title('Apprentissage-absence Max_TempN')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **apprentissage presence**

# %%
Cl32 = '/content/Max_tempN_preapp.xlsx' 
pre_app_Max_TempN= pd.read_excel(Cl32, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_app_Max_TempN
# Out:
#      Cs_longia  predict  predict0  predict1  Max_TempN
# 0            1        1  0.354841  0.645159      14443
# 1            1        1  0.047749  0.952251      14456
# 2            1        1  0.073439  0.926561      14502
# 3            1        1  0.465881  0.534119      14506
# 4            1        1  0.016424  0.983576      14531
# ..         ...      ...       ...       ...        ...
# 97           1        1  0.033764  0.966236      14939
# 98           1        1  0.081415  0.918585      14971
# 99           1        1  0.186040  0.813960      14996
# 100          1        1  0.102686  0.897314      15033
# 101          1        1  0.040067  0.959933      15112
#
# [102 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_app_Max_TempN["predict1"]
x = pre_app_Max_TempN["Max_TempN"]
plt.plot(x, y,"r")
plt.title('Apprentissage-presence Max_TempN')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val absence**

# %%
Cl33 = '/content/Max_tempN_absval.xlsx' 
abs_val_Max_TempN= pd.read_excel(Cl33, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_val_Max_TempN
# Out:
#     Cs_longia  predict  predict0  predict1  Max_TempN
# 0           0        0  0.560221  0.439779      14293
# 1           0        0  0.842887  0.157113      14540
# 2           0        0  0.721836  0.278164      14567
# 3           0        0  0.938562  0.061438      14579
# 4           0        0  0.953758  0.046242      14584
# 5           0        0  0.855130  0.144870      14628
# 6           0        0  0.595637  0.404363      14635
# 7           0        0  0.727151  0.272849      14640
# 8           0        0  0.681849  0.318151      14645
# 9           0        0  0.961293  0.038707      14660
# 10          0        0  0.941180  0.058820      14677
# 11          0        0  0.877161  0.122839      14689
# 12          0        0  0.714717  0.285283      14703
# 13          0        0  0.714717  0.285283      14703
# 14          0        0  0.984033  0.015967      14719
# 15          0        0  0.955479  0.044521      14723
# ...

# %%
y = abs_val_Max_TempN["predict0"]
x = abs_val_Max_TempN["Max_TempN"]
plt.title('Validation-absence Max_TempN')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val presence**

# %%
Cl34 = '/content/Max_tempN_preval.xlsx' 
pre_val_Max_TempN= pd.read_excel(Cl34, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_val_Max_TempN
# Out:
#     Cs_longia  predict  predict0  predict1  Max_TempN
# 0           1        1  0.159595  0.840405      14532
# 1           1        1  0.024679  0.975321      14533
# 2           1        1  0.068563  0.931437      14587
# 3           1        1  0.055254  0.944746      14590
# 4           1        1  0.005357  0.994643      14603
# 5           1        1  0.052266  0.947734      14647
# 6           1        1  0.014961  0.985039      14654
# 7           1        1  0.026526  0.973474      14666
# 8           1        1  0.008249  0.991751      14668
# 9           1        1  0.024510  0.975490      14699
# 10          1        1  0.092200  0.907800      14704
# 11          1        1  0.359125  0.640875      14714
# 12          1        1  0.207506  0.792494      14738
# 13          1        1  0.079594  0.920406      14997

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_val_Max_TempN["predict1"]
x = pre_val_Max_TempN["Max_TempN"]
plt.title('Validation-presence Max_TempN')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # VarT_ann_NDVI

# %% [markdown]
# **apprentissage absence**

# %%
Cl41 = '/content/Vart_ann_ndvi_absapp.xlsx' 
abs_app_VarT_ann_ndvi= pd.read_excel(Cl41, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_app_VarT_ann_ndvi
# Out:
#     Cs_longia  predict  predict0  predict1  VarT_ann_NDVI
# 0           0        0  0.957248  0.042752              0
# 1           0        0  0.912647  0.087353              0
# 2           0        0  0.881563  0.118437              2
# 3           0        0  0.978856  0.021144              2
# 4           0        0  0.822017  0.177983              3
# ..        ...      ...       ...       ...            ...
# 89          0        0  0.934478  0.065522             82
# 90          0        0  0.867445  0.132555             82
# 91          0        0  0.901600  0.098400             84
# 92          0        0  0.864176  0.135824             85
# 93          0        0  0.793011  0.206989             86
#
# [94 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

y = abs_app_VarT_ann_ndvi["predict0"]
x = abs_app_VarT_ann_ndvi["VarT_ann_NDVI"]
plt.plot(x, y,"r")
plt.title('Apprentissage-absence VarT_ann_NDVI')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **apprentissage presence**

# %%
Cl42 = '/content/Vart_ann_ndvi_preapp.xlsx' 
pre_app_VarT_ann_NDVI= pd.read_excel(Cl42, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_app_VarT_ann_NDVI
# Out:
#      Cs_longia  predict  predict0  predict1  VarT_ann_NDVI
# 0            1        1  0.118571  0.881429              1
# 1            1        1  0.055254  0.944746              1
# 2            1        1  0.172668  0.827332              2
# 3            1        1  0.057273  0.942727              6
# 4            1        1  0.354841  0.645159              9
# ..         ...      ...       ...       ...            ...
# 97           1        1  0.296956  0.703044             82
# 98           1        1  0.311906  0.688094             82
# 99           1        1  0.379265  0.620735             82
# 100          1        1  0.044201  0.955799             84
# 101          1        1  0.080478  0.919522             91
#
# [102 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_app_VarT_ann_NDVI["predict1"]
x = pre_app_VarT_ann_NDVI["VarT_ann_NDVI"]
plt.plot(x, y,"r")
plt.title('Apprentissage-presence VarT_ann_NDVI')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val absence**

# %%
Cl43 = '/content/Vart_ann_ndvi_absval.xlsx' 
abs_val_VarT_ann_NDVI= pd.read_excel(Cl43, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_val_VarT_ann_NDVI
# Out:
#     Cs_longia  predict  predict0  predict1  VarT_ann_NDVI
# 0           0        0  0.961293  0.038707              0
# 1           0        0  0.984033  0.015967              1
# 2           0        0  0.721836  0.278164              6
# 3           0        0  0.955479  0.044521              7
# 4           0        0  0.880801  0.119199             15
# 5           0        0  0.968626  0.031374             17
# 6           0        0  0.824535  0.175465             25
# 7           0        0  0.560221  0.439779             33
# 8           0        0  0.714717  0.285283             35
# 9           0        0  0.714717  0.285283             35
# 10          0        0  0.941180  0.058820             50
# 11          0        0  0.842887  0.157113             51
# 12          0        0  0.727151  0.272849             52
# 13          0        0  0.681849  0.318151             52
# 14          0        0  0.855130  0.144870             53
# ...

# %%
y = abs_val_VarT_ann_NDVI["predict0"]
x = abs_val_VarT_ann_NDVI["VarT_ann_NDVI"]
plt.title('Validation-absence VarT_ann_NDVI')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val presence**

# %%
Cl44 = '/content/Vart_ann_NDVI_preval.xlsx' 
pre_val_VarT_ann_NDVI= pd.read_excel(Cl44, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_val_VarT_ann_NDVI
# Out:
#     Cs_longia  predict  predict0  predict1  VarT_ann_NDVI
# 0           1        1  0.055254  0.944746              1
# 1           1        1  0.092200  0.907800              9
# 2           1        1  0.052266  0.947734             11
# 3           1        1  0.014961  0.985039             13
# 4           1        1  0.159595  0.840405             14
# 5           1        1  0.026526  0.973474             16
# 6           1        1  0.359125  0.640875             19
# 7           1        1  0.008249  0.991751             20
# 8           1        1  0.079594  0.920406             23
# 9           1        1  0.068563  0.931437             37
# 10          1        1  0.005357  0.994643             39
# 11          1        1  0.024679  0.975321             40
# 12          1        1  0.024510  0.975490             61
# 13          1        1  0.207506  0.792494             74

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_val_VarT_ann_NDVI["predict1"]
x = pre_val_VarT_ann_NDVI["VarT_ann_NDVI"]
plt.title('Validation-presence VarT_ann_NDVI')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Var_EVI

# %% [markdown]
# **apprentissage absence**

# %%
Cl51 = '/content/Var_EVI_abs_app.xlsx' 
abs_app_Var_EVI= pd.read_excel(Cl51, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_app_Var_EVI
# Out:
#     Cs_longia  predict  predict0  predict1  Var_EVI
# 0           0        0  0.741283  0.258717        0
# 1           0        0  0.881563  0.118437        1
# 2           0        0  0.971342  0.028658        1
# 3           0        0  0.947627  0.052373        1
# 4           0        0  0.891181  0.108819        1
# ..        ...      ...       ...       ...      ...
# 89          0        0  0.925770  0.074230      140
# 90          0        0  0.901600  0.098400      148
# 91          0        0  0.934478  0.065522      155
# 92          0        0  0.864176  0.135824      163
# 93          0        0  0.935088  0.064912      184
#
# [94 rows x 5 columns]

# %%
y = abs_app_Var_EVI["predict0"]
x = abs_app_Var_EVI["Var_EVI"]
plt.plot(x, y,"r")
plt.title('Apprentissage-absence Var_EVI')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **apprentissage presence**

# %%
Cl52 = '/content/Var_EVI_preapp.xlsx' 
pre_app_Var_EVI= pd.read_excel(Cl52, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_app_Var_EVI
# Out:
#      Cs_longia  predict  predict0  predict1  Var_EVI
# 0            1        1  0.081415  0.918585        0
# 1            1        1  0.065374  0.934626        0
# 2            1        1  0.011178  0.988822        0
# 3            1        1  0.011178  0.988822        0
# 4            1        1  0.102686  0.897314        0
# ..         ...      ...       ...       ...      ...
# 97           1        1  0.375757  0.624243      107
# 98           1        1  0.082263  0.917737      123
# 99           1        1  0.379265  0.620735      143
# 100          1        1  0.119814  0.880186      202
# 101          1        1  0.080478  0.919522      233
#
# [102 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_app_Var_EVI["predict1"]
x = pre_app_Var_EVI["Var_EVI"]
plt.plot(x, y,"r")
plt.title('Apprentissage-presence Var_EVI')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val absence**

# %%
Cl53 = '/content/Var_EVI_absval.xlsx' 
abs_val_Var_EVI= pd.read_excel(Cl53, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_val_Var_EVI
# Out:
#     Cs_longia  predict  predict0  predict1  Var_EVI
# 0           0        0  0.880801  0.119199        0
# 1           0        0  0.968626  0.031374        1
# 2           0        0  0.961293  0.038707        6
# 3           0        0  0.721836  0.278164       10
# 4           0        0  0.955479  0.044521       11
# 5           0        0  0.824535  0.175465       14
# 6           0        0  0.704766  0.295234       16
# 7           0        0  0.852824  0.147176       16
# 8           0        0  0.842887  0.157113       18
# 9           0        0  0.681849  0.318151       20
# 10          0        0  0.941180  0.058820       22
# 11          0        0  0.871982  0.128018       24
# 12          0        0  0.560221  0.439779       25
# 13          0        0  0.727151  0.272849       32
# 14          0        0  0.984033  0.015967       35
# 15          0        0  0.714717  0.285283       38
# 16          0        0  0.714717  0.285283       38
# ...

# %%
y = abs_val_Var_EVI["predict0"]
x = abs_val_Var_EVI["Var_EVI"]
plt.title('Validation-absence Var_EVI')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val presence**

# %%
Cl54 = '/content/Var_EVI_preval.xlsx' 
pre_val_Var_EVI= pd.read_excel(Cl54, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_val_Var_EVI
# Out:
#     Cs_longia  predict  predict0  predict1  Var_EVI
# 0           1        1  0.079594  0.920406        0
# 1           1        1  0.026526  0.973474        1
# 2           1        1  0.008249  0.991751        1
# 3           1        1  0.014961  0.985039        1
# 4           1        1  0.055254  0.944746        1
# 5           1        1  0.092200  0.907800        3
# 6           1        1  0.159595  0.840405        7
# 7           1        1  0.024679  0.975321        7
# 8           1        1  0.052266  0.947734       12
# 9           1        1  0.005357  0.994643       14
# 10          1        1  0.024510  0.975490       28
# 11          1        1  0.207506  0.792494       30
# 12          1        1  0.359125  0.640875       33
# 13          1        1  0.068563  0.931437       52

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_val_Var_EVI["predict1"]
x = pre_val_Var_EVI["Var_EVI"]
plt.title('Validation-presence Var_EVI')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Prof_ABS_SUB

# %% [markdown]
# **apprentissage absence**

# %%
Cl61 = '/content/ProfABSsub_absapp.xlsx' 
abs_app_ProfAbs_Sub= pd.read_excel(Cl61, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_app_ProfAbs_Sub
# Out:
#     Cs_longia  predict  predict0  predict1  ProfAbs_Sub
# 0           0        0  0.741283  0.258717            0
# 1           0        0  0.869198  0.130802            0
# 2           0        0  0.888156  0.111844            0
# 3           0        0  0.892253  0.107747            0
# 4           0        0  0.616228  0.383772            0
# ..        ...      ...       ...       ...          ...
# 89          0        0  0.971342  0.028658         5694
# 90          0        0  0.881563  0.118437         5965
# 91          0        0  0.922559  0.077441         6019
# 92          0        0  0.978856  0.021144         6929
# 93          0        0  0.958585  0.041415         8383
#
# [94 rows x 5 columns]

# %%
y = abs_app_ProfAbs_Sub["predict0"]
x = abs_app_ProfAbs_Sub["ProfAbs_Sub"]
plt.plot(x, y,"r")
plt.title('Apprentissage-absence ProfAbs_Sub')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **apprentissage presence**

# %%
Cl62 = '/content/Prof_abs_sub_preapp.xlsx' 
pre_app_ProfAbs_Sub= pd.read_excel(Cl62, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_app_ProfAbs_Sub
# Out:
#      Cs_longia  predict  predict0  predict1  ProfAbs_Sub
# 0            1        1  0.066352  0.933648            0
# 1            1        1  0.437786  0.562214            0
# 2            1        1  0.058699  0.941301            0
# 3            1        1  0.043394  0.956606            0
# 4            1        1  0.291164  0.708836            0
# ..         ...      ...       ...       ...          ...
# 97           1        1  0.102686  0.897314         5066
# 98           1        1  0.118571  0.881429         7886
# 99           1        1  0.129064  0.870936         9148
# 100          1        1  0.078622  0.921378         9523
# 101          1        1  0.040067  0.959933        11884
#
# [102 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_app_ProfAbs_Sub["predict1"]
x = pre_app_ProfAbs_Sub["ProfAbs_Sub"]
plt.plot(x, y,"r")
plt.title('Apprentissage-presence ProfAbs_Sub')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val absence**

# %%
Cl63 = '/content/ProfAbs_sub_absval.xlsx' 
abs_val_ProfAbs_Sub= pd.read_excel(Cl63, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_val_ProfAbs_Sub
# Out:
#     Cs_longia  predict  predict0  predict1  ProfAbs_Sub
# 0           0        0  0.560221  0.439779            0
# 1           0        0  0.888156  0.111844            0
# 2           0        0  0.888156  0.111844            0
# 3           0        0  0.961293  0.038707          118
# 4           0        0  0.852824  0.147176          334
# 5           0        0  0.721836  0.278164          579
# 6           0        0  0.955479  0.044521          599
# 7           0        0  0.877161  0.122839          857
# 8           0        0  0.595637  0.404363         1446
# 9           0        0  0.871982  0.128018         1602
# 10          0        0  0.704766  0.295234         1758
# 11          0        0  0.938562  0.061438         1810
# 12          0        0  0.898767  0.101233         2152
# 13          0        0  0.842887  0.157113         2320
# 14          0        0  0.953758  0.046242         2773
# 15          0        0  0.681849  0.318151         3012
# ...

# %%
y = abs_val_ProfAbs_Sub["predict0"]
x = abs_val_ProfAbs_Sub["ProfAbs_Sub"]
plt.title('Validation-absence ProfAbs_Sub')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val presence**

# %%
Cl64 = '/content/Profabs_sub_preval.xlsx' 
pre_val_ProfAbs_Sub= pd.read_excel(Cl64, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_val_ProfAbs_Sub
# Out:
#     Cs_longia  predict  predict0  predict1  ProfAbs_Sub
# 0           1        1  0.159595  0.840405            0
# 1           1        1  0.024510  0.975490          174
# 2           1        1  0.079594  0.920406          275
# 3           1        1  0.005357  0.994643          577
# 4           1        1  0.068563  0.931437          996
# 5           1        1  0.008249  0.991751         1068
# 6           1        1  0.207506  0.792494         1142
# 7           1        1  0.024679  0.975321         1277
# 8           1        1  0.092200  0.907800         1419
# 9           1        1  0.055254  0.944746         1470
# 10          1        1  0.026526  0.973474         2678
# 11          1        1  0.359125  0.640875         3253
# 12          1        1  0.014961  0.985039         4021
# 13          1        1  0.052266  0.947734         5724

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_val_ProfAbs_Sub["predict1"]
x = pre_val_ProfAbs_Sub["ProfAbs_Sub"]
plt.title('Validation-presence ProfAbs_Sub')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # IR_Moy

# %% [markdown]
# **apprentissage absence**

# %%
Cl71 = '/content/Ir_moy_absapp.xlsx' 
abs_app_IR_Moy= pd.read_excel(Cl71, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_app_IR_Moy
# Out:
#     Cs_longia  predict  predict0  predict1     IR_Moy
# 0           0        0  0.935088  0.064912   0.757812
# 1           0        0  0.871037  0.128963   1.007812
# 2           0        0  0.869999  0.130001   1.062500
# 3           0        0  0.714717  0.285283   1.687500
# 4           0        0  0.807829  0.192171   1.812500
# ..        ...      ...       ...       ...        ...
# 89          0        0  0.891181  0.108819  38.078125
# 90          0        0  0.869950  0.130050  39.171875
# 91          0        0  0.769923  0.230077  39.523438
# 92          0        0  0.616228  0.383772  51.656250
# 93          0        0  0.822017  0.177983  65.382812
#
# [94 rows x 5 columns]

# %%
y = abs_app_IR_Moy["predict0"]
x = abs_app_IR_Moy["IR_Moy"]
plt.plot(x, y,"r")
plt.title('Apprentissage-absence IR_Moy')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **apprentissage presence**

# %%
Cl72 = '/content/IR_moy_preapp.xlsx' 
pre_app_IR_Moy= pd.read_excel(Cl72, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_app_IR_Moy
# Out:
#      Cs_longia  predict  predict0  predict1     IR_Moy
# 0            1        1  0.020388  0.979612   1.046875
# 1            1        1  0.244474  0.755526   1.101562
# 2            1        1  0.157661  0.842339   1.164062
# 3            1        1  0.374542  0.625458   1.187500
# 4            1        1  0.473665  0.526335   1.187500
# ..         ...      ...       ...       ...        ...
# 97           1        1  0.040335  0.959665  50.351562
# 98           1        1  0.043810  0.956190  67.882812
# 99           1        1  0.043810  0.956190  67.882812
# 100          1        1  0.106390  0.893610  72.648438
# 101          1        1  0.029360  0.970640  85.796875
#
# [102 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_app_IR_Moy["predict1"]
x = pre_app_IR_Moy["IR_Moy"]
plt.plot(x, y,"r")
plt.title('Apprentissage-presence IR_Moy')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val absence**

# %%
Cl73 = '/content/Ir_moy_absval.xlsx' 
abs_val_IR_Moy= pd.read_excel(Cl73, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_val_IR_Moy
# Out:
#     Cs_longia  predict  predict0  predict1     IR_Moy
# 0           0        0  0.955479  0.044521   0.757812
# 1           0        0  0.880801  0.119199   0.820312
# 2           0        0  0.714717  0.285283   1.687500
# 3           0        0  0.714717  0.285283   1.687500
# 4           0        0  0.842887  0.157113   1.835938
# 5           0        0  0.727151  0.272849   2.226562
# 6           0        0  0.938562  0.061438   2.312500
# 7           0        0  0.681849  0.318151   2.367188
# 8           0        0  0.898767  0.101233   3.039062
# 9           0        0  0.941180  0.058820   3.179688
# 10          0        0  0.888156  0.111844   4.671875
# 11          0        0  0.855130  0.144870   5.328125
# 12          0        0  0.877161  0.122839   5.757812
# 13          0        0  0.704766  0.295234   6.335938
# 14          0        0  0.888156  0.111844   7.492188
# 15          0        0  0.984033  0.015967   7.515625
# ...

# %%
y = abs_val_IR_Moy["predict0"]
x = abs_val_IR_Moy["IR_Moy"]
plt.title('Validation-absence IR_Moy')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val presence**

# %%
Cl74 = '/content/Ir_moy_preval.xlsx' 
pre_val_IR_Moy= pd.read_excel(Cl74, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_val_IR_Moy
# Out:
#     Cs_longia  predict  predict0  predict1     IR_Moy
# 0           1        1  0.359125  0.640875   1.523438
# 1           1        1  0.052266  0.947734   2.046875
# 2           1        1  0.026526  0.973474   3.367188
# 3           1        1  0.008249  0.991751   4.351562
# 4           1        1  0.005357  0.994643   6.390625
# 5           1        1  0.014961  0.985039   6.671875
# 6           1        1  0.079594  0.920406  10.812500
# 7           1        1  0.055254  0.944746  11.070312
# 8           1        1  0.092200  0.907800  12.453125
# 9           1        1  0.024679  0.975321  16.171875
# 10          1        1  0.207506  0.792494  26.234375
# 11          1        1  0.068563  0.931437  29.000000
# 12          1        1  0.159595  0.840405  30.984375
# 13          1        1  0.024510  0.975490  33.046875

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_val_IR_Moy["predict1"]
x = pre_val_IR_Moy["IR_Moy"]
plt.title('Validation-presence IR_Moy')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Rad_Mai

# %% [markdown]
# **apprentissage absence**

# %%
Cl81 = '/content/Rad_mai_absapp.xlsx' 
abs_app_Rad_Mai= pd.read_excel(Cl81, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_app_Rad_Mai
# Out:
#     Cs_longia  predict  predict0  predict1  Rad_Mai
# 0           0        0  0.814310  0.185690    22597
# 1           0        0  0.556797  0.443203    22761
# 2           0        0  0.773237  0.226763    23317
# 3           0        0  0.935088  0.064912    23318
# 4           0        0  0.901600  0.098400    23328
# ..        ...      ...       ...       ...      ...
# 89          0        0  0.947627  0.052373    25135
# 90          0        0  0.922559  0.077441    25140
# 91          0        0  0.958585  0.041415    25198
# 92          0        0  0.919681  0.080319    25199
# 93          0        0  0.971342  0.028658    25211
#
# [94 rows x 5 columns]

# %%
y = abs_app_Rad_Mai["predict0"]
x = abs_app_Rad_Mai["Rad_Mai"]
plt.plot(x, y,"r")
plt.title('Apprentissage-absence Rad_Mai')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **apprentissage presence**

# %%
Cl82 = '/content/Rad_mai_preapp.xlsx' 
pre_app_Rad_Mai= pd.read_excel(Cl82, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_app_Rad_Mai
# Out:
#      Cs_longia  predict  predict0  predict1  Rad_Mai
# 0            1        1  0.016424  0.983576    21733
# 1            1        1  0.051958  0.948042    22165
# 2            1        1  0.051958  0.948042    22168
# 3            1        1  0.044486  0.955514    22264
# 4            1        1  0.005635  0.994365    22377
# ..         ...      ...       ...       ...      ...
# 97           1        1  0.040067  0.959933    24839
# 98           1        1  0.172668  0.827332    24920
# 99           1        1  0.024242  0.975758    24987
# 100          1        1  0.102686  0.897314    25017
# 101          1        1  0.186040  0.813960    25052
#
# [102 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_app_Rad_Mai["predict1"]
x = pre_app_Rad_Mai["Rad_Mai"]
plt.plot(x, y,"r")
plt.title('Apprentissage-presence Rad_Mai')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val absence**

# %%
Cl83 = '/content/Rad_mai_absval.xlsx' 
abs_val_Rad_Mai= pd.read_excel(Cl83, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_val_Rad_Mai
# Out:
#     Cs_longia  predict  predict0  predict1  Rad_Mai
# 0           0        0  0.727151  0.272849    23362
# 1           0        0  0.855130  0.144870    23410
# 2           0        0  0.953758  0.046242    23467
# 3           0        0  0.681849  0.318151    23477
# 4           0        0  0.714717  0.285283    23504
# 5           0        0  0.714717  0.285283    23504
# 6           0        0  0.941180  0.058820    23508
# 7           0        0  0.938562  0.061438    23523
# 8           0        0  0.704766  0.295234    23630
# 9           0        0  0.877161  0.122839    23702
# 10          0        0  0.595637  0.404363    23720
# 11          0        0  0.852824  0.147176    23732
# 12          0        0  0.842887  0.157113    23742
# 13          0        0  0.888156  0.111844    23762
# 14          0        0  0.888156  0.111844    23806
# 15          0        0  0.955479  0.044521    23822
# 16          0        0  0.871982  0.128018    23857
# ...

# %%
y = abs_val_Rad_Mai["predict0"]
x = abs_val_Rad_Mai["Rad_Mai"]
plt.title('Validation-absence Rad_Mai')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val presence**

# %%
Cl84 = '/content/Rad_mai_preval.xlsx' 
pre_val_Rad_Mai= pd.read_excel(Cl84, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_val_Rad_Mai
# Out:
#     Cs_longia  predict  predict0  predict1  Rad_Mai
# 0           1        1  0.026526  0.973474    22120
# 1           1        1  0.014961  0.985039    22146
# 2           1        1  0.092200  0.907800    22312
# 3           1        1  0.008249  0.991751    22869
# 4           1        1  0.005357  0.994643    22953
# 5           1        1  0.024510  0.975490    23287
# 6           1        1  0.068563  0.931437    23433
# 7           1        1  0.359125  0.640875    23515
# 8           1        1  0.207506  0.792494    23547
# 9           1        1  0.024679  0.975321    23616
# 10          1        1  0.079594  0.920406    23717
# 11          1        1  0.159595  0.840405    23954
# 12          1        1  0.055254  0.944746    24067
# 13          1        1  0.052266  0.947734    24391

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_val_Rad_Mai["predict1"]
x = pre_val_Rad_Mai["Rad_Mai"]
plt.title('Validation-presence Rad_Mai')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Tmax_Fev

# %% [markdown]
# **apprentissage absence**

# %%
Cl91 = '/content/Tmax_fev_absapp.xlsx' 
abs_app_Tmax_Fev= pd.read_excel(Cl91, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_app_Tmax_Fev
# Out:
#     Cs_longia  predict  predict0  predict1   Tmax_Fev
# 0           0        0  0.869950  0.130050   9.000000
# 1           0        0  0.942915  0.057085  10.200000
# 2           0        0  0.803799  0.196201  10.800000
# 3           0        0  0.919493  0.080507  11.100000
# 4           0        0  0.945273  0.054727  11.500000
# ..        ...      ...       ...       ...        ...
# 89          0        0  0.714717  0.285283  21.900000
# 90          0        0  0.958585  0.041415  22.299999
# 91          0        0  0.741283  0.258717  22.600000
# 92          0        0  0.957248  0.042752  22.799999
# 93          0        0  0.912647  0.087353  22.799999
#
# [94 rows x 5 columns]

# %%
y = abs_app_Tmax_Fev["predict0"]
x = abs_app_Tmax_Fev["Tmax_Fev"]
plt.plot(x, y,"r")
plt.title('Apprentissage-absence Tmax_Fev')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **apprentissage presence**

# %%
Cl92 = '/content/Tmax_fev_preapp.xlsx' 
pre_app_Tmax_Fev= pd.read_excel(Cl92, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_app_Tmax_Fev
# Out:
#      Cs_longia  predict  predict0  predict1  Tmax_Fev
# 0            1        1  0.047749  0.952251      10.1
# 1            1        1  0.354841  0.645159      10.6
# 2            1        1  0.029360  0.970640      11.3
# 3            1        1  0.070643  0.929357      11.9
# 4            1        1  0.042189  0.957811      11.9
# ..         ...      ...       ...       ...       ...
# 97           1        1  0.011178  0.988822      22.6
# 98           1        1  0.011178  0.988822      22.6
# 99           1        1  0.057273  0.942727      22.9
# 100          1        1  0.065374  0.934626      22.9
# 101          1        1  0.055254  0.944746      23.0
#
# [102 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_app_Tmax_Fev["predict1"]
x = pre_app_Tmax_Fev["Tmax_Fev"]
plt.plot(x, y,"r")
plt.title('Apprentissage-presence Tmax_Fev')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val absence**

# %%
Cl93 = '/content/Tmax_fev_absval.xlsx' 
abs_val_Tmax_Fev= pd.read_excel(Cl93, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_val_Tmax_Fev
# Out:
#     Cs_longia  predict  predict0  predict1   Tmax_Fev
# 0           0        0  0.560221  0.439779   5.600000
# 1           0        0  0.721836  0.278164  11.500000
# 2           0        0  0.871982  0.128018  16.200001
# 3           0        0  0.852824  0.147176  17.700001
# 4           0        0  0.595637  0.404363  17.799999
# 5           0        0  0.704766  0.295234  18.000000
# 6           0        0  0.938562  0.061438  18.000000
# 7           0        0  0.842887  0.157113  18.000000
# 8           0        0  0.888156  0.111844  18.100000
# 9           0        0  0.888156  0.111844  18.100000
# 10          0        0  0.953758  0.046242  18.200001
# 11          0        0  0.877161  0.122839  18.500000
# 12          0        0  0.824535  0.175465  18.700001
# 13          0        0  0.955479  0.044521  19.000000
# 14          0        0  0.855130  0.144870  19.200001
# 15          0        0  0.941180  0.058820  19.500000
# ...

# %%
y = abs_val_Tmax_Fev["predict0"]
x = abs_val_Tmax_Fev["Tmax_Fev"]
plt.title('Validation-absence Tmax_Fev')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val presence**

# %%
Cl94 = '/content/Tmax_fev_preval.xlsx' 
pre_val_Tmax_Fev= pd.read_excel(Cl94, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_val_Tmax_Fev
# Out:
#     Cs_longia  predict  predict0  predict1   Tmax_Fev
# 0           1        1  0.159595  0.840405  11.700000
# 1           1        1  0.068563  0.931437  12.600000
# 2           1        1  0.024510  0.975490  13.700000
# 3           1        1  0.207506  0.792494  14.900000
# 4           1        1  0.024679  0.975321  16.200001
# 5           1        1  0.052266  0.947734  16.200001
# 6           1        1  0.359125  0.640875  21.400000
# 7           1        1  0.005357  0.994643  21.500000
# 8           1        1  0.008249  0.991751  21.700001
# 9           1        1  0.079594  0.920406  22.000000
# 10          1        1  0.026526  0.973474  22.200001
# 11          1        1  0.092200  0.907800  22.500000
# 12          1        1  0.014961  0.985039  22.700001
# 13          1        1  0.055254  0.944746  23.000000

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_val_Tmax_Fev["predict1"]
x = pre_val_Tmax_Fev["Tmax_Fev"]
plt.title('Validation-presence Tmax_Fev')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Tmax_Avril

# %% [markdown]
# **apprentissage absence**

# %%
Cl101 = '/content/tmax_avril_absapp.xlsx' 
abs_app_Tmax_Avril= pd.read_excel(Cl101, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_app_Tmax_Avril
# Out:
#     Cs_longia  predict  predict0  predict1  Tmax_Avril
# 0           0        0  0.869950  0.130050   15.100000
# 1           0        0  0.942915  0.057085   16.200001
# 2           0        0  0.803799  0.196201   16.799999
# 3           0        0  0.919493  0.080507   17.100000
# 4           0        0  0.945273  0.054727   17.600000
# ..        ...      ...       ...       ...         ...
# 89          0        0  0.978856  0.021144   25.900000
# 90          0        0  0.947627  0.052373   26.000000
# 91          0        0  0.922559  0.077441   28.100000
# 92          0        0  0.919681  0.080319   29.000000
# 93          0        0  0.958585  0.041415   29.600000
#
# [94 rows x 5 columns]

# %%
y = abs_app_Tmax_Avril["predict0"]
x = abs_app_Tmax_Avril["Tmax_Avril"]
plt.plot(x, y,"r")
plt.title('Apprentissage-absence Tmax_Avril')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **apprentissage presence**

# %%
Cl102 = '/content/Tmax_avril_preapp.xlsx' 
pre_app_Tmax_Avril= pd.read_excel(Cl102, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_app_Tmax_Avril
# Out:
#      Cs_longia  predict  predict0  predict1  Tmax_Avril
# 0            1        1  0.047749  0.952251   16.400000
# 1            1        1  0.029360  0.970640   16.500000
# 2            1        1  0.354841  0.645159   16.600000
# 3            1        1  0.070643  0.929357   17.900000
# 4            1        1  0.040335  0.959665   18.100000
# ..         ...      ...       ...       ...         ...
# 97           1        1  0.009833  0.990167   26.100000
# 98           1        1  0.186040  0.813960   26.200001
# 99           1        1  0.102686  0.897314   26.900000
# 100          1        1  0.040067  0.959933   27.600000
# 101          1        1  0.065374  0.934626   27.700001
#
# [102 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_app_Tmax_Avril["predict1"]
x = pre_app_Tmax_Avril["Tmax_Avril"]
plt.plot(x, y,"r")
plt.title('Apprentissage-presence Tmax_Avril')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val absence**

# %%
Cl103 = '/content/Tmax_absval.xlsx' 
abs_val_Tmax_Avril= pd.read_excel(Cl103, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
abs_val_Tmax_Avril
# Out:
#     Cs_longia  predict  predict0  predict1  Tmax_Avril
# 0           0        0  0.560221  0.439779   12.200000
# 1           0        0  0.721836  0.278164   17.000000
# 2           0        0  0.842887  0.157113   20.600000
# 3           0        0  0.953758  0.046242   20.700001
# 4           0        0  0.938562  0.061438   20.700001
# 5           0        0  0.871982  0.128018   20.799999
# 6           0        0  0.852824  0.147176   20.900000
# 7           0        0  0.704766  0.295234   21.200001
# 8           0        0  0.855130  0.144870   21.400000
# 9           0        0  0.595637  0.404363   21.799999
# 10          0        0  0.941180  0.058820   21.900000
# 11          0        0  0.955479  0.044521   21.900000
# 12          0        0  0.888156  0.111844   22.799999
# 13          0        0  0.888156  0.111844   22.900000
# 14          0        0  0.681849  0.318151   23.000000
# 15          0        0  0.877161  0.122839   23.000000
# ...

# %%
y = abs_val_Tmax_Avril["predict0"]
x = abs_val_Tmax_Avril["Tmax_Avril"]
plt.title('Validation-absence Tmax_Avril')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **val presence**

# %%
Cl104 = '/content/Tmax_avril_preval.xlsx' 
pre_val_Tmax_Avril= pd.read_excel(Cl104, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
pre_val_Tmax_Avril
# Out:
#     Cs_longia  predict  predict0  predict1  Tmax_Avril
# 0           1        1  0.159595  0.840405   18.299999
# 1           1        1  0.068563  0.931437   18.500000
# 2           1        1  0.024510  0.975490   19.200001
# 3           1        1  0.207506  0.792494   19.700001
# 4           1        1  0.024679  0.975321   21.100000
# 5           1        1  0.052266  0.947734   21.500000
# 6           1        1  0.026526  0.973474   24.900000
# 7           1        1  0.055254  0.944746   24.900000
# 8           1        1  0.008249  0.991751   25.100000
# 9           1        1  0.092200  0.907800   25.200001
# 10          1        1  0.005357  0.994643   25.200001
# 11          1        1  0.014961  0.985039   25.200001
# 12          1        1  0.359125  0.640875   25.299999
# 13          1        1  0.079594  0.920406   27.000000

# %%
import numpy as np
import matplotlib.pyplot as plt

y = pre_val_Tmax_Avril["predict1"]
x = pre_val_Tmax_Avril["Tmax_Avril"]
plt.title('Validation-presence Tmax_Avril')
plt.plot(x, y,"r")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.
